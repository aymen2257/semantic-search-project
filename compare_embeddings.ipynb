# %%
# !pip install sentence-transformers numpy scipy scikit-learn plotly
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (5.4.1)
# Requirement already satisfied: numpy in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (2.4.4)
# Requirement already satisfied: scipy in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (1.17.1)
# Requirement already satisfied: scikit-learn in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (1.8.0)
# Collecting plotly
#   Downloading plotly-6.7.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from sentence-transformers) (5.6.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from sentence-transformers) (1.11.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.20.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from plotly) (26.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: typer in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.24.2)
# Requirement already satisfied: setuptools<82 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: colorama in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from tqdm>=4.0.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: anyio in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.13.0)
# Requirement already satisfied: certifi in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from typer->huggingface-hub>=0.23.0->sentence-transformers) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from typer->huggingface-hub>=0.23.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from typer->huggingface-hub>=0.23.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from typer->huggingface-hub>=0.23.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from rich>=12.3.0->typer->huggingface-hub>=0.23.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from rich>=12.3.0->typer->huggingface-hub>=0.23.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\desktop\pfe_26\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.23.0->sentence-transformers) (0.1.2)
# Downloading plotly-6.7.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.9 MB 9.6 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.9 MB 13.4 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.9 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 14.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 12.8 MB/s eta 0:00:00
# Downloading narwhals-2.20.0-py3-none-any.whl (449 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-2.20.0 plotly-6.7.0
# [notice] A new release of pip is available: 24.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer

# Load a pre-trained sentence embedding model
model_name = 'all-MiniLM-L6-v2'
model = SentenceTransformer(model_name)

print(f"Model '{model_name}' loaded successfully.")
# Output: Model 'all-MiniLM-L6-v2' loaded successfully.
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model 'all-MiniLM-L6-v2' loaded successfully.

# %%
import numpy as np

sentences = [
    "The delivery arrived on time.",
    "My package was delivered promptly.",
    "Vector databases store numerical representations.",
    "How can I optimize database queries?",
    "The weather today is sunny and warm."
]

# Generate embeddings for the sentences
embeddings = model.encode(sentences)

# Check the dimensions of the embeddings
print(f"Shape of embeddings matrix: {embeddings.shape}")


# Display the first few dimensions of the first embedding
print(f"First 5 dimensions of the first sentence embedding:\n{embeddings[0, :5]}")
# Output: First 5 dimensions of the first sentence embedding:
# Out:
# Shape of embeddings matrix: (5, 384)
# First 5 dimensions of the first sentence embedding:
# [-0.05027558  0.04267898 -0.01072991  0.04200416  0.01438534]

# %%
from scipy.spatial.distance import cosine
num_sentences = len (sentences)
similarity_matrix = np.zeros((num_sentences,num_sentences))
for i in range(num_sentences):
    for j in range(num_sentences):
        similarity = 1 - cosine(embeddings[i],embeddings[j])
        similarity_matrix[i,j] = similarity
print("Pairwise Cosine Similarity Matrix:")
print(np.round(similarity_matrix,2))
# Out:
# Pairwise Cosine Similarity Matrix:
# [[ 1.    0.7   0.    0.03  0.15]
#  [ 0.7   1.    0.03  0.09  0.12]
#  [ 0.    0.03  1.    0.27 -0.01]
#  [ 0.03  0.09  0.27  1.    0.04]
#  [ 0.15  0.12 -0.01  0.04  1.  ]]

# %%
from sklearn.decomposition import PCA
import plotly.graph_objects as go

# Reduce dimensions to 2D using PCA
pca = PCA(n_components=2)
embeddings_2d = pca.fit_transform(embeddings)

# Create a scatter plot (using pre-calculated example coordinates for consistency)
# Replace these coordinates with the actual output of your PCA transformation
# if you run the code yourself.
example_coords = {
    "x": [-0.15, -0.18, 0.10, 0.25, -0.02],
    "y": [0.08, 0.10, -0.05, -0.12, 0.01]
}

fig = go.Figure(data=go.Scatter(
    # x=embeddings_2d[:, 0], # Use actual PCA output
    # y=embeddings_2d[:, 1], # Use actual PCA output
    x=example_coords["x"], # Using example values
    y=example_coords["y"], # Using example values
    mode='markers+text',
    marker=dict(
        size=10,
        color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd'], # Example colors
        opacity=0.8
    ),
    text=[f"'{s[:20]}...'" for s in sentences], # Display shortened text labels
    textposition='top center'
))

fig.update_layout(
    title='2D PCA Projection of Sentence Embeddings',
    xaxis_title='Principal Component 1',
    yaxis_title='Principal Component 2',
    width=700,
    height=500,
    showlegend=False
)

# To display the plot (e.g., in a Jupyter Notebook or save to HTML)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 # Reduce dimensions to 2D using PCA
#       5 pca = PCA(n_components=2)
# ----> 6 embeddings_2d = pca.fit_transform(embeddings)
#       8 # Create a scatter plot (using pre-calculated example coordinates for consistency)
#       9 # Replace these coordinates with the actual output of your PCA transformation
#      10 # if you run the code yourself.
#      11 example_coords = {
#      12     "x": [-0.15, -0.18, 0.10, 0.25, -0.02],
#      13     "y": [0.08, 0.10, -0.05, -0.12, 0.01]
#      14 }
#
# NameError: name 'embeddings' is not defined
